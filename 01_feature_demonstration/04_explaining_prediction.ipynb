# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import ktrain
from sklearn.datasets import fetch_20newsgroups

# %%
class_names = ['alt.atheism', 'comp.sys.ibm.pc.hardware', 'sci.space', 'talk.politics.guns']
train = fetch_20newsgroups(subset='train', remove=['headers', 'footers', 'quotes'], categories=class_names, shuffle=False)
test = fetch_20newsgroups(subset='test', remove=['headers', 'footers', 'quotes'], categories=class_names, shuffle=False)

# %%
train_ds, test_ds, preproc = ktrain.text.texts_from_array(
    x_train=train.data, y_train=train.target,
    x_test=test.data, y_test=test.target,
    preprocess_mode='standard', class_names=class_names, maxlen=600
)
# Out:
# language: en
# Word Counts: 30716
# Nrows: 2209
# 2209 train sequences
# train sequence lengths:
# 	mean : 187
# 	95percentile : 600
# 	99percentile : 1892
# x_train shape: (2209,600)
# y_train shape: (2209, 4)
# Is Multi-Label? False
# 1469 test sequences
# test sequence lengths:
# 	mean : 152
# 	95percentile : 492
# 	99percentile : 1144
# x_test shape: (1469,600)
# y_test shape: (1469, 4)
# task: text classification

# %%
model = ktrain.text.text_classifier('nbsvm', train_data=train_ds, preproc=preproc)
# Out:
# Is Multi-Label? False
# compiling word ID features...
# maxlen is 600
# building document-term matrix... this may take a few moments...
# rows: 1-2209
# computing log-count ratios...
# done.

# %%
learner = ktrain.get_learner(model, train_data=train_ds, batch_size=64)

# %%
learner.autofit(2e-2, 5, verbose=2)
# Out:
# begin training using triangular learning rate policy with max lr of 0.02...
# Epoch 1/5
# 35/35 - 2s - loss: 0.5141 - accuracy: 0.8728 - 2s/epoch - 60ms/step
# Epoch 2/5
# 35/35 - 0s - loss: 0.1799 - accuracy: 0.9597 - 147ms/epoch - 4ms/step
# Epoch 3/5
# 35/35 - 0s - loss: 0.1359 - accuracy: 0.9688 - 160ms/epoch - 5ms/step
# Epoch 4/5
# 35/35 - 0s - loss: 0.1128 - accuracy: 0.9742 - 171ms/epoch - 5ms/step
# Epoch 5/5
# 35/35 - 0s - loss: 0.0982 - accuracy: 0.9751 - 151ms/epoch - 4ms/step

# %%
predictor = ktrain.get_predictor(learner.model, preproc)

# %%
print('Ground truth:', class_names[test.target[12]])
predictor.explain(test.data[12])
# Out:
# Ground truth: sci.space
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=sci.space
#
# </b>
#
#
#     (probability <b>0.848</b>, score <b>1.676</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.502
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 90.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.826
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 98.03%); opacity: 0.80" title="0.022">are</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.63%); opacity: 0.81" title="0.068">you</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.05%); opacity: 0.83" title="0.221">guys</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.42%); opacity: 0.82" title="0.150">talking</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.71%); opacity: 0.81" title="0.066">about</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.62%); opacity: 0.81" title="0.047">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.73%); opacity: 0.83" title="0.231">soviet</span><span style="opacity: 0.80"> &quot;</span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.611">shuttle</span><span style="opacity: 0.80">&quot;? </span><span style="background-color: hsl(120, 100.00%, 88.32%); opacity: 0.83" title="0.277">it</span><span style="opacity: 0.80">&#x27;</span><span style="background-color: hsl(0, 100.00%, 92.94%); opacity: 0.82" title="-0.135">s</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.20%); opacity: 0.81" title="-0.056">not</span><span style="opacity: 0.80"> &quot;</span><span style="background-color: hsl(120, 100.00%, 93.32%); opacity: 0.82" title="0.125">soyuz</span><span style="opacity: 0.80">&quot;, </span><span style="background-color: hsl(120, 100.00%, 90.01%); opacity: 0.83" title="0.222">it</span><span style="opacity: 0.80">&#x27;</span><span style="background-color: hsl(0, 100.00%, 93.31%); opacity: 0.82" title="-0.125">s</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.94%); opacity: 0.81" title="0.061">called</span><span style="opacity: 0.80"> &quot;</span><span style="background-color: hsl(120, 100.00%, 94.32%); opacity: 0.81" title="0.099">buran</span><span style="opacity: 0.80">&quot; </span><span style="background-color: hsl(120, 100.00%, 93.56%); opacity: 0.81" title="0.119">which</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.03%); opacity: 0.81" title="-0.082">means</span><span style="opacity: 0.80"> &quot;</span><span style="background-color: hsl(120, 100.00%, 93.74%); opacity: 0.81" title="0.114">snow</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.42%); opacity: 0.80" title="0.004">storm</span><span style="opacity: 0.80">.&quot; (</span><span style="background-color: hsl(0, 100.00%, 96.24%); opacity: 0.81" title="-0.055">at</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.50%); opacity: 0.80" title="-0.031">least</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.26%); opacity: 0.82" title="0.184">that</span><span style="opacity: 0.80">&#x27;</span><span style="background-color: hsl(0, 100.00%, 96.98%); opacity: 0.80" title="-0.040">s</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.69%); opacity: 0.81" title="0.046">what</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.49%); opacity: 0.80" title="-0.031">they</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.97%); opacity: 0.81" title="-0.108">call</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.39%); opacity: 0.81" title="0.097">it</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.57%); opacity: 0.81" title="0.069">on</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 70.96 ...
#     </p>

# %%
print('Ground truth:', class_names[test.target[5]])
predictor.explain(test.data[5])
# Out:
# Ground truth: comp.sys.ibm.pc.hardware
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=comp.sys.ibm.pc.hardware
#
# </b>
#
#
#     (probability <b>0.990</b>, score <b>5.399</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.941
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 96.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.542
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 83.04%); opacity: 0.86" title="0.444">wondering</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 86.44%); opacity: 0.84" title="0.322">if</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.52%); opacity: 0.81" title="0.066">somebody</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.98%); opacity: 0.81" title="-0.038">could</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.75%); opacity: 0.82" title="0.159">tell</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.14%); opacity: 0.80" title="0.035">me</span><span style="opacity: 0.80"> if </span><span style="background-color: hsl(0, 100.00%, 80.57%); opacity: 0.87" title="-0.539">we</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.42%); opacity: 0.82" title="-0.115">can</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.07%); opacity: 0.81" title="0.099">change</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.67%); opacity: 0.82" title="0.134">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.60%); opacity: 0.81" title="-0.045">cluster</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.65%); opacity: 0.81" title="0.085">size</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.33%); opacity: 0.80" title="-0.004">of</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.39%); opacity: 0.83" title="0.197">my</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 61.40%); opacity: 0.99" title="1.437">ide</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 78.04%); opacity: 0.88" title="0.642">drive</span><span style="opacity: 0.80">. </span><span style="background-color: hsl(120, 100.00%, 84.95%); opacity: 0.85" title="0.374">normally</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.08%); opacity: 0.82" title="0.123">i</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.85%); opacity: 0.81" title="-0.081">can</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.85%); opacity: 0.81" title="-0.081">do</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.24%); opacity: 0.80" title="-0.017">it</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.99%); opacity: 0.80" title="0.038">with</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.30%); opacity: 0.81" title="-0.093">norton</span><span style="opacity: 0.80">&#x27;</span><span style="background-color: hsl(0, 100.00%, 99.95%); opacity: 0.80" title="-0.000">s</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.53%); opacity: 0.81" title="-0.046">calibrat</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.48%); opacity: 0.83" title="0.194">on</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 80.45%); opacity: 0.87" title="0.544">mfm</span><span style="opacity: 0.80">/</span><span style="background-color: hsl(120, 100.00%, 87.87%); opacity: 0.84" title="0.275">rll</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 63.61%); opacity: 0.97" title="1.321">drives</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.74%); opacity: 0.80" title="-0.011">but</span><span style= ...
#     </p>

# %%
print('Ground truth:', class_names[test.target[32]])
predictor.explain(test.data[32])
# Out:
# Ground truth: alt.atheism
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=alt.atheism
#
# </b>
#
#
#     (probability <b>1.000</b>, score <b>17.837</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +18.320
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 98.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.484
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">i </span><span style="background-color: hsl(0, 100.00%, 94.93%); opacity: 0.81" title="-0.058">recall</span><span style="opacity: 0.80"> a </span><span style="background-color: hsl(120, 100.00%, 91.49%); opacity: 0.82" title="0.122">discussion</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.89%); opacity: 0.81" title="0.029">i</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.10%); opacity: 0.82" title="0.109">had</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.38%); opacity: 0.82" title="0.104">heard</span><span style="opacity: 0.80"> years </span><span style="background-color: hsl(120, 100.00%, 95.74%); opacity: 0.81" title="0.045">ago</span><span style="opacity: 0.80">. </span><span style="background-color: hsl(0, 100.00%, 95.88%); opacity: 0.81" title="-0.043">it</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.43%); opacity: 0.80" title="0.011">went</span><span style="opacity: 0.80"> something </span><span style="background-color: hsl(0, 100.00%, 99.58%); opacity: 0.80" title="-0.002">like</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.27%); opacity: 0.81" title="0.037">this</span><span style="opacity: 0.80">: </span><span style="background-color: hsl(120, 100.00%, 86.20%); opacity: 0.84" title="0.243">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.41%); opacity: 0.81" title="0.035">problem</span><span style="opacity: 0.80"> with </span><span style="background-color: hsl(120, 100.00%, 81.61%); opacity: 0.87" title="0.366">omnipotence</span><span style="opacity: 0.80"> (</span><span style="background-color: hsl(0, 100.00%, 89.30%); opacity: 0.83" title="-0.169">at</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.63%); opacity: 0.81" title="-0.080">least</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.84%); opacity: 0.81" title="-0.059">as</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.75%); opacity: 0.82" title="0.137">i</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.75%); opacity: 0.82" title="0.137">perceive</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 92.62%); opacity: 0.82" title="-0.099">it</span><span style="opacity: 0.80">) </span><span style="background-color: hsl(0, 100.00%, 94.84%); opacity: 0.81" title="-0.059">as</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.39%); opacity: 0.81" title="0.036">personified</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.08%); opacity: 0.82" title="0.091">by</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 85.46%); opacity: 0.85" title="0.262">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 83.30%); opacity: 0.86" title="0.319">christian</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 63.38%); opacity: 0.98" title="0.979">god</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 87.46%); opacity: 0.84" title="0.212">ideal</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.48%); opacity: 0.82" title="0.102">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.56%); opacity: 0.81" title="0.033">that</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 87.60%); opacity: 0.84" title="-0.208">it</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100 ...

# %%
print('Ground truth:', class_names[test.target[98]])
predictor.explain(test.data[98])
# Out:
# Ground truth: talk.politics.guns
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=talk.politics.guns
#
# </b>
#
#
#     (probability <b>0.654</b>, score <b>1.311</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.486
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 95.53%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.175
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 92.02%); opacity: 0.82" title="-0.100">this</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.70%); opacity: 0.80" title="0.017">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 86.94%); opacity: 0.84" title="0.203">quite</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.43%); opacity: 0.82" title="0.076">corect</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(0, 100.00%, 99.21%); opacity: 0.80" title="-0.004">but</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.01%); opacity: 0.81" title="-0.067">a</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.79%); opacity: 0.82" title="0.123">bullet</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.74%); opacity: 0.81" title="-0.071">hitting</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.14%); opacity: 0.80" title="0.023">a</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 75.22%); opacity: 0.90" title="0.506">burned</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.24%); opacity: 0.85" title="0.265">body</span><span style="opacity: 0.80"> with </span><span style="background-color: hsl(0, 100.00%, 97.02%); opacity: 0.80" title="-0.025">little</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.02%); opacity: 0.81" title="-0.066">energy</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.67%); opacity: 0.82" title="-0.107">will</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.85%); opacity: 0.81" title="0.039">show</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 89.68%); opacity: 0.83" title="-0.145">virtually</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.43%); opacity: 0.82" title="0.076">no</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.02%); opacity: 0.81" title="-0.037">deformation</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(0, 100.00%, 94.66%); opacity: 0.81" title="-0.057">ie</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.99%); opacity: 0.80" title="-0.025">a</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.05%); opacity: 0.82" title="0.100">hollow</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.60%); opacity: 0.80" title="0.018">point</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.06%); opacity: 0.80" title="-0.005">probably</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.80%); opacity: 0.82" title="0.087">would</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.34%); opacity: 0.81" title="0.033">not</span><span style="opacity: 0.80"> expand, </span><span style="background-color: hsl(0, 100.00%, 95.74%); opacity: 0.81" title="-0.041">an</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.74%); opacity: 0.82" title="-0.105">fmj</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.50%); opacity: 0.81" title="0.059">would</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.79%); opacity: 0.82" title="0.104">be</span><span style="opacity: 0.80"> &quot;</span><span style="background-color: hsl(120, 100.00%, 95.71%); opacity: 0.81" title="0.041" ...

# %%
# Source: https://en.wikipedia.org/wiki/Space_exploration
predictor.explain('Space exploration is the use of astronomy and space technology to explore outer space. While the exploration of space is carried out mainly by astronomers with telescopes, its physical exploration though is conducted both by unmanned robotic space probes and human spaceflight. Space exploration, like its classical form astronomy, is one of the main sources for space science. ')
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=sci.space
#
# </b>
#
#
#     (probability <b>1.000</b>, score <b>16.260</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +16.580
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 98.74%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.320
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 60.50%); opacity: 1.00" title="1.638">space</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 80.40%); opacity: 0.87" title="0.602">exploration</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.70%); opacity: 0.81" title="-0.069">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.78%); opacity: 0.80" title="0.001">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.02%); opacity: 0.80" title="0.008">use</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.57%); opacity: 0.80" title="0.030">of</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.50%); opacity: 0.85" title="0.430">astronomy</span><span style="opacity: 0.80"> and </span><span style="background-color: hsl(120, 100.00%, 61.03%); opacity: 0.99" title="1.607">space</span><span style="opacity: 0.80"> technology to </span><span style="background-color: hsl(120, 100.00%, 91.40%); opacity: 0.82" title="0.186">explore</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.04%); opacity: 0.85" title="0.449">outer</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.668">space</span><span style="opacity: 0.80">. </span><span style="background-color: hsl(120, 100.00%, 95.02%); opacity: 0.81" title="0.085">while</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.38%); opacity: 0.82" title="0.156">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 78.36%); opacity: 0.88" title="0.694">exploration</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.38%); opacity: 0.80" title="-0.017">of</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.10%); opacity: 1.00" title="1.662">space</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.40%); opacity: 0.80" title="-0.017">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.27%); opacity: 0.83" title="0.222">carried</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 87.58%); opacity: 0.84" title="0.314">out</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.70%); opacity: 0.82" title="0.177">mainly</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.23%); opacity: 0.81" title="0.105">by</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.05%); opacity: 0.85" title="0.449">astronomers</span><span style="opacity: 0.80"> with </span><span style="background-color: hsl(120, 100.00%, 95.20%); opacity: 0.81" title="0.081">telescopes</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 93.45%); opacity: 0.82" title="0.126">its</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.31%); opacity: 0.80" title="0.018">physical</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 80.95%); opacity: 0.87" title="0.578">exploration</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.05%); opacity: 0.80" title="0.022">though</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.43%); opacity: 0.80" title="0.016">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 88.67%); opacity: 0.83" title="0.275">conducted</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(12 ...

# %%
# Source: https://en.wikipedia.org/wiki/Gun
predictor.explain('A gun is a ranged weapon designed to use a shooting tube (gun barrel) to launch typically solid projectiles, but can also project pressurized liquid (e.g. water guns/cannons, spray guns for painting or pressure washing, projected water disruptors, and technically also flamethrowers), gas (e.g. light-gas gun) or even charged particles (e.g. plasma gun[disambiguation needed]). Solid projectiles may be free-flying (as with bullets and artillery shells) or tethered (as with Taser guns, spearguns and harpoon guns). A large-caliber gun is also referred to as a cannon.')
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=talk.politics.guns
#
# </b>
#
#
#     (probability <b>0.995</b>, score <b>5.905</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.298
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 97.13%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.393
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 93.28%); opacity: 0.82" title="0.102">a</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 67.95%); opacity: 0.95" title="0.953">gun</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.86%); opacity: 0.80" title="-0.020">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 88.88%); opacity: 0.83" title="-0.210">a</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.42%); opacity: 0.80" title="0.003">ranged</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 64.41%); opacity: 0.97" title="1.106">weapon</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 92.32%); opacity: 0.82" title="-0.124">designed</span><span style="opacity: 0.80"> to </span><span style="background-color: hsl(120, 100.00%, 96.61%); opacity: 0.81" title="0.038">use</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.98%); opacity: 0.82" title="0.156">a</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 71.89%); opacity: 0.92" title="0.790">shooting</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 88.11%); opacity: 0.84" title="-0.231">tube</span><span style="opacity: 0.80"> (</span><span style="background-color: hsl(120, 100.00%, 71.43%); opacity: 0.92" title="0.808">gun</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.08%); opacity: 0.80" title="0.031">barrel</span><span style="opacity: 0.80">) </span><span style="background-color: hsl(0, 100.00%, 87.27%); opacity: 0.84" title="-0.255">to</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 68.50%); opacity: 0.94" title="-0.930">launch</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.99%); opacity: 0.80" title="-0.018">typically</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 64.68%); opacity: 0.97" title="-1.095">solid</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.57%); opacity: 0.81" title="-0.039">projectiles</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(0, 100.00%, 98.00%); opacity: 0.80" title="-0.018">but</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.38%); opacity: 0.81" title="0.042">can</span><span style="opacity: 0.80"> also </span><span style="background-color: hsl(0, 100.00%, 72.31%); opacity: 0.92" title="-0.773">project</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.90%); opacity: 0.81" title="-0.069">pressurized</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 82.52%); opacity: 0.86" title="-0.401">liquid</span><span style="opacity: 0.80"> (e.</span><span style="background-color: hsl(120, 100.00%, 92.88%); opacity: 0.82" title="0.111">g</span><span style="opacity: 0.80">. </span><span style="background-color: hsl(0, 100.00%, 94.41%); opacity: 0.81" title="-0.079">water</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 62.83%); opacity: 0.98" title="1.178">guns</span><span style="opacity: 0.80">/</span><span style="background-color: hsl(120, 100.00%, 97.77%); opacity: 0.80" title="0.021">cannons</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(0, 100.00%, 97.39%); opacity: 0.80" title="-0.026">spray</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 62.83%); opacity: 0.98" title="1.178">guns</span><span style="opacity: 0.80"> for </span><span style="background-color: hsl(0, 100.00%, 96.37%); opacity: 0.81" title ...

# %%
# Source: https://en.wikipedia.org/wiki/AMD_Phenom
predictor.explain('Phenom is the 64-bit AMD desktop processor line based on the K10 microarchitecture, in what AMD calls family 10h (10 hex, i.e. 16 in normal decimal numbers) processors, sometimes incorrectly called "K10h". Triple-core versions (codenamed Toliman) belong to the Phenom 8000 series and quad cores (codenamed Agena) to the AMD Phenom X4 9000 series. The first processor in the family was released in 2007. ')
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=comp.sys.ibm.pc.hardware
#
# </b>
#
#
#     (probability <b>0.942</b>, score <b>4.794</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.292
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 96.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.498
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 94.91%); opacity: 0.81" title="-0.068">phenom</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.21%); opacity: 0.81" title="0.062">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.16%); opacity: 0.81" title="0.063">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.50%); opacity: 0.82" title="0.118">64</span><span style="opacity: 0.80">-</span><span style="background-color: hsl(120, 100.00%, 97.62%); opacity: 0.80" title="0.023">bit</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 62.80%); opacity: 0.98" title="1.157">amd</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 85.72%); opacity: 0.85" title="0.295">desktop</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.05%); opacity: 0.83" title="0.202">processor</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.83%); opacity: 0.80" title="-0.020">line</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.37%); opacity: 0.81" title="-0.078">based</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.37%); opacity: 0.82" title="-0.099">on</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.42%); opacity: 0.81" title="-0.077">the</span><span style="opacity: 0.80"> k10 </span><span style="background-color: hsl(120, 100.00%, 95.58%); opacity: 0.81" title="0.055">microarchitecture</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 94.17%); opacity: 0.81" title="0.082">in</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.19%); opacity: 0.83" title="0.198">what</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.284">amd</span><span style="opacity: 0.80"> calls </span><span style="background-color: hsl(120, 100.00%, 95.21%); opacity: 0.81" title="0.062">family</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.66%); opacity: 0.80" title="0.010">10h</span><span style="opacity: 0.80"> (10 </span><span style="background-color: hsl(120, 100.00%, 95.25%); opacity: 0.81" title="0.061">hex</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 91.82%); opacity: 0.82" title="0.133">i</span><span style="opacity: 0.80">.</span><span style="background-color: hsl(0, 100.00%, 93.85%); opacity: 0.81" title="-0.089">e</span><span style="opacity: 0.80">. </span><span style="background-color: hsl(120, 100.00%, 82.24%); opacity: 0.86" title="0.403">16</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.58%); opacity: 0.82" title="0.139">in</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 87.18%); opacity: 0.84" title="0.253">normal</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.24%); opacity: 0.80" title="-0.004">decimal</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.75%); opacity: 0.80" title="-0.001">numbers</span><span style="opacity: 0.80">) </span><span style="background-color: hsl(120, 100.00%, 90.04%); opacity: 0.83" title="0.176">processors</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 94.55%); opacity: 0.81" title="0.074">sometimes</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.55%); opacity: 0.81" title="0.074">incorrectly</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.08%); opacity: 0.8 ...
